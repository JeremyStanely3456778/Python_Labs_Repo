# %% [markdown]
# 9.1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

data = np.arange(10)
plt.plot(data)

df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.hist(np.random.standard_normal(100), bins=20, color="black", alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal (30));

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
sns.histplot(df['median_income'])

# %%
sns.histplot(df['population'])

# %%
fig = plt.figure()
ax1 = fig.add_subplot()
data = np.random.standard_normal(30).cumsum()
ax1.plot(df['population'], color="black", linestyle="dashed", label="Default");
ax1.legend()

# %%
fig, ax = plt.subplots()
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color="orange", alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color="yellow", alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
 color="red", alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# 9.2-9.4

# %%
s = pd.Series(np.random.standard_normal(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

# %%
fig, axes = plt.subplots(2, 1)
df['total_bedrooms'].plot.bar(ax=axes[0], color="black", alpha=0.7)
df['population'].plot.barh(ax=axes[1], color="black", alpha=0.7)

# %%
df.plot.barh(stacked=True, alpha=0.5)

# %%
ax = sns.regplot(x="population", y="median_income", data=df)

# %%
sns.pairplot(df, diag_kind="kde", plot_kws={"alpha": 0.2})
